# %%
#Ihsan Muchsin

import itertools as it

def perm(infile, outfile):
    '''
    Given: 1) An input file containing a positive integer n≤7. 2) The name of output file
    Return: The total number of permutations of length n, followed by a list of all such permutations (in any order). Plus an output file containing the result.
    '''
    
    with open(infile, 'r') as fin:
        n = int(fin.readline())
    
    num_list = [i for i in range(1, n+1)]
    possible_perm = list(it.permutations(num_list)) #list of permutation
    total_perm = len(possible_perm) #total number of permutation
    
    with open(outfile, 'w') as fout:
        fout.write(str(total_perm) + '\n')
        
        possible_perm_str = []
        for el in possible_perm:
            e_str = [str(e) for e in el]
            el_str = ' '.join(e_str)
            possible_perm_str.append(el_str) #convert to string so it is possible to write in output
            
        fout.write('\n'.join(possible_perm_str))
    
    return (total_perm, possible_perm)

# %%
infile = 'rosalind_perm.txt'
outfile = 'perm_sol.txt'

res = perm(infile, outfile)

print(res[0])
for p in res[1]:
    print(*p)
# Out:
# 120
# 1 2 3 4 5
# 1 2 3 5 4
# 1 2 4 3 5
# 1 2 4 5 3
# 1 2 5 3 4
# 1 2 5 4 3
# 1 3 2 4 5
# 1 3 2 5 4
# 1 3 4 2 5
# 1 3 4 5 2
# 1 3 5 2 4
# 1 3 5 4 2
# 1 4 2 3 5
# 1 4 2 5 3
# 1 4 3 2 5
# 1 4 3 5 2
# 1 4 5 2 3
# 1 4 5 3 2
# 1 5 2 3 4
# 1 5 2 4 3
# 1 5 3 2 4
# 1 5 3 4 2
# 1 5 4 2 3
# 1 5 4 3 2
# 2 1 3 4 5
# 2 1 3 5 4
# 2 1 4 3 5
# 2 1 4 5 3
# 2 1 5 3 4
# 2 1 5 4 3
# 2 3 1 4 5
# 2 3 1 5 4
# 2 3 4 1 5
# 2 3 4 5 1
# 2 3 5 1 4
# 2 3 5 4 1
# 2 4 1 3 5
# 2 4 1 5 3
# 2 4 3 1 5
# 2 4 3 5 1
# 2 4 5 1 3
# 2 4 5 3 1
# 2 5 1 3 4
# 2 5 1 4 3
# 2 5 3 1 4
# 2 5 3 4 1
# 2 5 4 1 3
# 2 5 4 3 1
# 3 1 2 4 5
# 3 1 2 5 4
# 3 1 4 2 5
# 3 1 4 5 2
# 3 1 5 2 4
# 3 1 5 4 2
# 3 2 1 4 5
# 3 2 1 5 4
# 3 2 4 1 5
# 3 2 4 5 1
# 3 2 5 1 4
# 3 2 5 4 1
# 3 4 1 2 5
# 3 4 1 5 2
# 3 4 2 1 5
# 3 4 2 5 1
# 3 4 5 1 2
# 3 4 5 2 1
# 3 5 1 2 4
# 3 5 1 4 2
# 3 5 2 1 4
# 3 5 2 4 1
# 3 5 4 1 2
# 3 5 4 2 1
# 4 1 2 3 5
# 4 1 2 5 3
# 4 1 3 2 5
# 4 1 3 5 2
# 4 1 5 2 3
# 4 1 5 3 2
# 4 2 1 3 5
# 4 2 1 5 3
# 4 2 3 1 5
# 4 2 3 5 1
# ...
