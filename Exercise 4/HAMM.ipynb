# %%
def hamm(s1, s2):
    hamm_dist = 0
    for i in range(len(s1)):
        if s1[i] != s2[i]:
            hamm_dist += 1
    return hamm_dist

s1 = '...'
s2 = '...'
res = hamm(s1, s2)
print (res)
# Out:
# 494
